# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://wsearch.nlm.nih.gov/ws/query"

parameters = {"db" : "healthTopics", "term" : "heart attack", "retmode": "json"}

res_ = requests.get(url=url,params=parameters)
res_.raise_for_status()
data = res_.text

# %%
res_
# Out:
# <Response [200]>

# %%
data
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<nlmSearchResult>\n  <term>heart attack</term>\n  <file>viv_SMBTN3</file>\n  <server>pvlb7srch16</server>\n  <count>91</count>\n  <retstart>0</retstart>\n  <retmax>10</retmax>\n  <list num="91" start="0" per="10">\n    <document rank="0" url="https://medlineplus.gov/heartattack.html">\n      <content name="title">&lt;span class="qt0"&gt;&lt;span class="qt2"&gt;Heart&lt;/span&gt;&lt;/span&gt;&lt;span class="qt2"&gt; &lt;/span&gt;&lt;span class="qt1"&gt;&lt;span class="qt2"&gt;Attack&lt;/span&gt;&lt;/span&gt;</content>\n      <content name="organizationName">National Library of Medicine</content>\n      <content name="altTitle">MI</content>\n      <content name="altTitle">&lt;span class="qt0"&gt;&lt;span class="qt1"&gt;&lt;span class="qt2"&gt;Myocardial Infarction&lt;/span&gt;&lt;/span&gt;&lt;/span&gt;</content>\n      <content name="FullSummary">&lt;p&gt;Each year almost 800,000 Americans have a &lt;span class="qt0"&gt;&lt;span class="qt2"&gt;h
# ...

# %%
res_.headers.get("Content-Type")
# Out:
# 'text/xml; charset=UTF-8'
