# %%
# !pip3 install sentence-transformers faiss-cpu transformers torch newspaper3k langchain beautifulsoup4

# !pip3 install --upgrade langchain

# !pip3 install pyngrok streamlit --quiet

# !pip3 install lxml[html_clean]

# !pip3 install langchain-text-splitters
# Out:
# ...
# zsh:1: no matches found: lxml[html_clean]
# ...

# %%
from pyngrok import ngrok
import os

# Authenticate ngrok
# !ngrok authtoken 38YGxp7yGom5VY3ld30srXcONvo_4JusvnXANKaoxVwBcxtzS

# Kill any existing tunnels
ngrok.kill()

# Expose Streamlit port 8501
public_url = ngrok.connect(8501, "http", bind_tls=True)
print("Streamlit public URL:", public_url)
# Out:
# Authtoken saved to configuration file: /Users/manjunathpopuri/Library/Application Support/ngrok/ngrok.yml
# Streamlit public URL: NgrokTunnel: "https://misgivingly-faunal-maurita.ngrok-free.dev" -> "http://localhost:8501"

# %%
# Run Streamlit app in background
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8519
#   Network URL: http://192.168.1.64:8519
#
# 2026-01-20 23:52:22.184 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ~~~~~~~~~~~~~~~~~~~~~~~~^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#   File "/opt/anaconda3/lib/python3.13/site-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
# ...
